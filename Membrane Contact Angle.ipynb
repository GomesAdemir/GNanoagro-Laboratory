# %%
#---------- linkedin.com/in/ademirgomesneto/ ----------------#

import pandas as pd
import matplotlib.pyplot as plt

# %%
lista = pd.read_csv('angulo_membranas.csv', delimiter=';')

# %%
listaUser = lista[['Tratamentor', 'Membrana', 'CA', 'Tempo']]
listaCNF = lista[['Tratamentor', 'Membrana', 'CA', 'Tempo']]

# %%
#Remove Treated
tratamentor = listaUser.loc[(listaUser['Tratamentor']!='Untreated')]
CNF = listaUser.drop(tratamentor.index)

# %%
#------------------------Data Freme for each type of membrane-------------------------------#
#Only CNF all
Tremove = listaCNF.loc[(listaCNF['Membrana']!='CNF')]
CNF1 = listaUser.drop(Tremove.index)
#Only CNF Treated
TreCNF = CNF1.loc[(CNF1['Tratamentor']!='Untreated')]
#Only CNF Untreated
UnCNF = CNF1.loc[(CNF1['Tratamentor']!='Treated')]
#------------------------------------------------------------------------#
#Only T5 all
OnlyT5 = listaCNF.loc[(listaCNF['Membrana']=='T5')]
#Only T5 Untreated
OnlyT5Un = OnlyT5.loc[(OnlyT5['Tratamentor']=='Untreated')]
#Only T5 Treated
OnlyT5Te = OnlyT5.loc[(OnlyT5['Tratamentor']=='Treated')]
#------------------------------------------------------------------------#
#Only t10 all
OnlyT10 = listaCNF.loc[(listaCNF['Membrana']=='T10')]
#Only T10 Untreated
OnlyT10Un = OnlyT10.loc[(OnlyT10['Tratamentor']=='Untreated')]
#Only T10 Treated
OnlyT10Te = OnlyT10.loc[(OnlyT10['Tratamentor']=='Treated')]

# %%
#------T10 UnTreated------- Data freme for each time

OnlyT10Un5 = OnlyT10Un.loc[(OnlyT10Un['Tempo']==5)]

OnlyT10Un10 = OnlyT10Un.loc[(OnlyT10Un['Tempo']==10)]

OnlyT10Un15 = OnlyT10Un.loc[(OnlyT10Un['Tempo']==15)]

OnlyT10Un20 = OnlyT10Un.loc[(OnlyT10Un['Tempo']==20)]

OnlyT10Un25 = OnlyT10Un.loc[(OnlyT10Un['Tempo']==25)]

OnlyT10Un30 = OnlyT10Un.loc[(OnlyT10Un['Tempo']==30)]
#display(OnlyT5Un30)

#------T10 treated------- Data freme for each time

OnlyT10Te5 = OnlyT10Te.loc[(OnlyT10Te['Tempo']==5)]

OnlyT10Te10 = OnlyT10Te.loc[(OnlyT10Te['Tempo']==10)]

OnlyT10Te15 = OnlyT10Te.loc[(OnlyT10Te['Tempo']==15)]

OnlyT10Te20 = OnlyT10Te.loc[(OnlyT10Te['Tempo']==20)]

OnlyT10Te25 = OnlyT10Te.loc[(OnlyT10Te['Tempo']==25)]

OnlyT10Te30 = OnlyT10Te.loc[(OnlyT10Te['Tempo']==30)]

# %%
#--------------Mean t10 Treated-------------------#

#Mean t10 Treated time 5
countOnlyT10Te5 = len(OnlyT10Te5.index)
sumOnlyT10Te5 = OnlyT10Te5['CA'].sum()
MeanOnlyT10Te5 = sumOnlyT10Te5/countOnlyT10Te5

#Mean t10 Treated time 10
countOnlyT10Te10 = len(OnlyT10Te10.index)
sumOnlyT10Te10 = OnlyT10Te10['CA'].sum()
MeanOnlyT10Te10 = sumOnlyT10Te10/countOnlyT10Te10

#Mean t10 Treated time 15
countOnlyT10Te15 = len(OnlyT10Te15.index)
sumOnlyT10Te15 = OnlyT10Te15['CA'].sum()
MeanOnlyT10Te15 = sumOnlyT10Te15/countOnlyT10Te15

#Mean t10 Treated time 20
countOnlyT10Te20 = len(OnlyT10Te20.index)
sumOnlyT10Te20 = OnlyT10Te20['CA'].sum()
MeanOnlyT10Te20 = sumOnlyT10Te20/countOnlyT10Te20

#Mean t10 Treated time 25
countOnlyT10Te25 = len(OnlyT10Te25.index)
sumOnlyT10Te25 = OnlyT10Te25['CA'].sum()
MeanOnlyT10Te25 = sumOnlyT10Te25/countOnlyT10Te25

#Mean t10 Treated time 30
countOnlyT10Te30 = len(OnlyT10Te30.index)
sumOnlyT10Te30 = OnlyT10Te30['CA'].sum()
MeanOnlyT10Te30 = sumOnlyT10Te30/countOnlyT10Te30

#display(OnlyT10Te30)

# %%
#--------------Mean t10 Untreated-------------------#

#Mean t10 Untreated time 5
countOnlyT10Un5 = len(OnlyT10Un5.index)
sumOnlyT10Un5 = OnlyT10Un5['CA'].sum()
MeanOnlyT10Un5 = sumOnlyT10Un5/countOnlyT10Un5

#Mean t10 Untreated time 10
countOnlyT10Un10 = len(OnlyT10Un10.index)
sumOnlyT10Un10 = OnlyT10Un10['CA'].sum()
MeanOnlyT10Un10 = sumOnlyT10Un10/countOnlyT10Un10

#Mean t10 Untreated time 15
countOnlyT10Un15 = len(OnlyT10Un15.index)
sumOnlyT10Un15 = OnlyT10Un15['CA'].sum()
MeanOnlyT10Un15 = sumOnlyT10Un15/countOnlyT10Un15

#Mean t10 Untreated time 20
countOnlyT10Un20 = len(OnlyT10Un20.index)
sumOnlyT10Un20 = OnlyT10Un20['CA'].sum()
MeanOnlyT10Un20 = sumOnlyT10Un20/countOnlyT10Un20

#Mean t10 Untreated time 25
countOnlyT10Un25 = len(OnlyT10Un25.index)
sumOnlyT10Un25 = OnlyT10Un25['CA'].sum()
MeanOnlyT10Un25 = sumOnlyT10Un25/countOnlyT10Un25

#Mean t10 Untreated time 30
countOnlyT10Un30 = len(OnlyT10Un30.index)
sumOnlyT10Un30 = OnlyT10Un30['CA'].sum()
MeanOnlyT10Un30 = sumOnlyT10Un30/countOnlyT10Un30

# %%
#------T5 UnTreated------- Data freme for each time

OnlyT5Un5 = OnlyT5Un.loc[(OnlyT5Un['Tempo']==5)]

OnlyT5Un10 = OnlyT5Un.loc[(OnlyT5Un['Tempo']==10)]

OnlyT5Un15 = OnlyT5Un.loc[(OnlyT5Un['Tempo']==15)]

OnlyT5Un20 = OnlyT5Un.loc[(OnlyT5Un['Tempo']==20)]

OnlyT5Un25 = OnlyT5Un.loc[(OnlyT5Un['Tempo']==25)]

OnlyT5Un30 = OnlyT5Un.loc[(OnlyT5Un['Tempo']==30)]
#display(OnlyT5Un30)

#------T5 treated------- Data freme for each time

OnlyT5Te5 = OnlyT5Te.loc[(OnlyT5Te['Tempo']==5)]

OnlyT5Te10 = OnlyT5Te.loc[(OnlyT5Te['Tempo']==10)]

OnlyT5Te15 = OnlyT5Te.loc[(OnlyT5Te['Tempo']==15)]

OnlyT5Te20 = OnlyT5Te.loc[(OnlyT5Te['Tempo']==20)]

OnlyT5Te25 = OnlyT5Te.loc[(OnlyT5Te['Tempo']==25)]

OnlyT5Te30 = OnlyT5Te.loc[(OnlyT5Te['Tempo']==30)]
#display(OnlyT5Te30)

# %%
#--------------Mean t5 Untreated-------------------#

#Mean t5 Untreated time 5
countOnlyT5Un5 = len(OnlyT5Un5.index)
sumOnlyT5Un5 = OnlyT5Un5['CA'].sum()
MeanOnlyT5Un5 = sumOnlyT5Un5/countOnlyT5Un5

#Mean t5 Untreated time 10
countOnlyT5Un10 = len(OnlyT5Un10.index)
sumOnlyT5Un10 = OnlyT5Un10['CA'].sum()
MeanOnlyT5Un10 = sumOnlyT5Un10/countOnlyT5Un10

#Mean t5 Untreated time 15
countOnlyT5Un15 = len(OnlyT5Un5.index)
sumOnlyT5Un15 = OnlyT5Un15['CA'].sum()
MeanOnlyT5Un15 = sumOnlyT5Un15/countOnlyT5Un15

#Mean t5 Untreated time 20
countOnlyT5Un20 = len(OnlyT5Un20.index)
sumOnlyT5Un20 = OnlyT5Un20['CA'].sum()
MeanOnlyT5Un20 = sumOnlyT5Un20/countOnlyT5Un20

#Mean t5 Untreated time 25
countOnlyT5Un25 = len(OnlyT5Un25.index)
sumOnlyT5Un25 = OnlyT5Un25['CA'].sum()
MeanOnlyT5Un25 = sumOnlyT5Un25/countOnlyT5Un25

#Mean t5 Untreated time 30
countOnlyT5Un30 = len(OnlyT5Un30.index)
sumOnlyT5Un30 = OnlyT5Un30['CA'].sum()
MeanOnlyT5Un30 = sumOnlyT5Un30/countOnlyT5Un30

#--------------Mean t5 Treated-------------------#

#Mean t5 Treated time 5
countOnlyT5Te5 = len(OnlyT5Te5.index)
sumOnlyT5Te5 = OnlyT5Te5['CA'].sum()
MeanOnlyT5Te5 = sumOnlyT5Te5/countOnlyT5Te5

#Mean t5 Treated time 10
countOnlyT5Te10 = len(OnlyT5Te10.index)
sumOnlyT5Te10 = OnlyT5Te10['CA'].sum()
MeanOnlyT5Te10 = sumOnlyT5Te10/countOnlyT5Te10

#Mean t5 Treated time 15
countOnlyT5Te15 = len(OnlyT5Te15.index)
sumOnlyT5Te15 = OnlyT5Te15['CA'].sum()
MeanOnlyT5Te15 = sumOnlyT5Te15/countOnlyT5Te15

#Mean t5 Treated time 20
countOnlyT5Te20 = len(OnlyT5Te20.index)
sumOnlyT5Te20 = OnlyT5Te20['CA'].sum()
MeanOnlyT5Te20 = sumOnlyT5Te20/countOnlyT5Te20

#Mean t5 Treated time 25
countOnlyT5Te25 = len(OnlyT5Te25.index)
sumOnlyT5Te25 = OnlyT5Te25['CA'].sum()
MeanOnlyT5Te25 = sumOnlyT5Te25/countOnlyT5Te25

#Mean t5 Treated time 30
countOnlyT5Te30 = len(OnlyT5Te30.index)
sumOnlyT5Te30 = OnlyT5Te30['CA'].sum()
MeanOnlyT5Te30 = sumOnlyT5Te30/countOnlyT5Te30

# %%
                #CNF#
#----------MEAN TREATED CNF-------------#

#Mean CNF5 Treated
countTreCNF5 = len(TreCNF5.index)
sumTreCNF5 = TreCNF5['CA'].sum()
MeanTreCNF5 = sumTreCNF5/countTreCNF5

# %%
#------CNF Treated------- Data freme for each time

TreCNF5 = TreCNF.loc[(TreCNF['Tempo']==5)]

TreCNF10 = TreCNF.loc[(TreCNF['Tempo']==10)]

TreCNF15 = TreCNF.loc[(TreCNF['Tempo']==15)]

TreCNF20 = TreCNF.loc[(TreCNF['Tempo']==20)]

TreCNF25 = TreCNF.loc[(TreCNF['Tempo']==25)]

TreCNF30 = TreCNF.loc[(TreCNF['Tempo']==30)]
#display(TreCNF25)

# %%
                #CNF#
#----------MEAN TREATED CNF-------------#

#Mean CNF5 Treated
countTreCNF5 = len(TreCNF5.index)
sumTreCNF5 = TreCNF5['CA'].sum()
MeanTreCNF5 = sumTreCNF5/countTreCNF5
      
#Mean CNF10 Treated
countTreCNF10 = len(TreCNF10.index)
sumTreCNF10 = TreCNF10['CA'].sum()
MeanTreCNF10 = sumTreCNF10/countTreCNF10

#Mean CNF15 Treated
countTreCNF15 = len(TreCNF15.index)
sumTreCNF15 = TreCNF15['CA'].sum()
MeanTreCNF15 = sumTreCNF15/countTreCNF15

#Mean CNF20 Treated
countTreCNF20 = len(TreCNF20.index)
sumTreCNF20 = TreCNF20['CA'].sum()
MeanTreCNF20 = sumTreCNF20/countTreCNF20

#Mean CNF25 Treated
countTreCNF25 = len(TreCNF25.index)
sumTreCNF25 = TreCNF25['CA'].sum()
MeanTreCNF25 = sumTreCNF25/countTreCNF25

#Mean CNF30 Treated
countTreCNF30 = len(TreCNF30.index)
sumTreCNF30 = TreCNF30['CA'].sum()
MeanTreCNF30 = sumTreCNF30/countTreCNF30
#display(MeanTreCNF30)

#----------MEAN UNTREATED CNF-------------#

#Mean CNF5 Untreated
countUnCNF5 = len(UnCNF5.index)
sumUnCNF5 = UnCNF5['CA'].sum()
MeanUnCNF5 = sumUnCNF5/countUnCNF5

#Mean CNF10 Untreated
countUnCNF10 = len(UnCNF10.index)
sumUnCNF10 = UnCNF10['CA'].sum()
MeanUnCNF10 = sumUnCNF10/countUnCNF10

#Mean CNF15 Untreated
countUnCNF15 = len(UnCNF15.index)
sumUnCNF15 = UnCNF15['CA'].sum()
MeanUnCNF15 = sumUnCNF15/countUnCNF15

#Mean CNF20 Untreated
countUnCNF20 = len(UnCNF20.index)
sumUnCNF20 = UnCNF20['CA'].sum()
MeanUnCNF20 = sumUnCNF20/countUnCNF20

#Mean CNF25 Untreated
countUnCNF25 = len(UnCNF25.index)
sumUnCNF25 = UnCNF25['CA'].sum()
MeanUnCNF25 = sumUnCNF25/countUnCNF25

#Mean CNF30 Untreated
countUnCNF30 = len(UnCNF30.index)
sumUnCNF30 = UnCNF30['CA'].sum()
MeanUnCNF30 = sumUnCNF30/countUnCNF30
#display(MeanUnCNF30)

# %%
#------Untreated--- Data freme for each time -------------
UnCNF5 = UnCNF.loc[(UnCNF['Tempo']==5)]
#display(UnCNF5)

UnCNF10 = UnCNF.loc[(UnCNF['Tempo']==10)]
#display(UnCNF10)

UnCNF15 = UnCNF.loc[(UnCNF['Tempo']==15)]
#display(UnCNF15)

UnCNF20 = UnCNF.loc[(UnCNF['Tempo']==20)]
#display(UnCNF20)

UnCNF25 = UnCNF.loc[(UnCNF['Tempo']==25)]
#display(UnCNF25)

UnCNF30 = UnCNF.loc[(UnCNF['Tempo']==30)]
#display(UnCNF30)

#------Treated------ Data freme for each time -------------

TreCNF5 = TreCNF.loc[(TreCNF['Tempo']==5)]
#display(TreCNF5)

TreCNF10 = TreCNF.loc[(TreCNF['Tempo']==10)]
#display(TreCNF10)

TreCNF15 = TreCNF.loc[(TreCNF['Tempo']==15)]
#display(TreCNF15)

TreCNF20 = TreCNF.loc[(TreCNF['Tempo']==20)]
#display(TreCNF20)

TreCNF25 = TreCNF.loc[(TreCNF['Tempo']==25)]
#display(TreCNF25)

TreCNF30 = TreCNF.loc[(TreCNF['Tempo']==30)]
#display(TreCNF25)

# %%
# -------------------------------Subtitle------------------------------------------#
plt.figure(figsize=(20,10))


#------------------------------Grafic-------------------------------------#

#Data Frame Mean Untreated CNF = obj0
obj0 = {'MeanUnCNF': [MeanUnCNF5, MeanUnCNF10, MeanUnCNF15, MeanUnCNF20, MeanUnCNF25, MeanUnCNF30], 'Time': [5, 10, 15, 20, 25, 30]}
DfMeanUnCNF = pd.DataFrame(data=obj0)
#Data Frame Mean Treated CNF = obj1
obj1 = {'MeanTreCNF': [MeanTreCNF5, MeanTreCNF10, MeanTreCNF15, MeanTreCNF20, MeanTreCNF25, MeanTreCNF30], 'Time': [5, 10, 15, 20, 25, 30]}
DfMeanTreCNF = pd.DataFrame(data=obj1)
#Data Frame Mean Treated t10 = obj2
obj2 = {'MeanTeT10':[MeanOnlyT10Te5, MeanOnlyT10Te10, MeanOnlyT10Te15, MeanOnlyT10Te20, MeanOnlyT10Te25, MeanOnlyT10Te30], 'Time': [5, 10, 15, 20, 25, 30]}
DfMeanTeT10 = pd.DataFrame(data=obj2)
#Data Frame Mean Untreated t10 = obj3
obj3 = {'MeanUnT10':[MeanOnlyT10Un5, MeanOnlyT10Un10, MeanOnlyT10Un15, MeanOnlyT10Un20, MeanOnlyT10Un25, MeanOnlyT10Un30], 'Time': [5, 10, 15, 20, 25, 30]}
DfMeanUnT10 = pd.DataFrame(data=obj3)
#Data Frame Mean Untreated t5 = obj4
obj4 = {'MeanUnT5':[MeanOnlyT5Un5, MeanOnlyT5Un10, MeanOnlyT5Un15, MeanOnlyT5Un20, MeanOnlyT5Un25, MeanOnlyT5Un30], 'Time': [5, 10, 15, 20, 25, 30]}
DfMeanUnT5 = pd.DataFrame(data=obj4)
#Data Frame Mean Treated t5 = obj5
obj5 = {'MeanTeT5':[MeanOnlyT5Te5, MeanOnlyT5Te10, MeanOnlyT5Te15, MeanOnlyT5Te20, MeanOnlyT5Te25, MeanOnlyT5Te30], 'Time': [5, 10, 15, 20, 25, 30]}
DfMeanTeT5 = pd.DataFrame(data=obj5)

#------------------------------Grafic-------------------------------------#
#Grafic Untreated CNF
plt.plot(DfMeanUnCNF['Time'], DfMeanUnCNF['MeanUnCNF'])
#Grafic Treated CNF
plt.plot(DfMeanTreCNF['Time'], DfMeanTreCNF['MeanTreCNF'])
#Grafic Treated T10
plt.plot(DfMeanTeT10['Time'], DfMeanTeT10['MeanTeT10'])
#Grafic Untreated T10
plt.plot(DfMeanUnT10['Time'], DfMeanUnT10['MeanUnT10'])
#Grafic Tereated T5
plt.plot(DfMeanTeT5['Time'], DfMeanTeT5['MeanTeT5'])
#Grafic Untereated T5
plt.plot(DfMeanUnT5['Time'], DfMeanUnT5['MeanUnT5'])



#------------------------------Grafic Scatter-------------------------------------#

plt.scatter(DfMeanUnCNF['Time'], DfMeanUnCNF['MeanUnCNF'])
plt.scatter(DfMeanTreCNF['Time'], DfMeanTreCNF['MeanTreCNF'])
plt.scatter(DfMeanTeT10['Time'], DfMeanTeT10['MeanTeT10'])
plt.scatter(DfMeanUnT10['Time'], DfMeanUnT10['MeanUnT10'])
plt.scatter(DfMeanTeT5['Time'], DfMeanTeT5['MeanTeT5'])
plt.scatter(DfMeanUnT5['Time'], DfMeanUnT5['MeanUnT5'])


#Blue = Untreated CNF
#Yellow = treated CNF
#Green = Treaty T10
#Red = Untreated T10
#Purple = Treaty T5
#Brown = untreated T5
